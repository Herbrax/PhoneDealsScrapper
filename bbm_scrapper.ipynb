# %%
import xml.etree.ElementTree as ET
import requests
import csv
from datetime import datetime
from dataclasses import dataclass
from typing import List
import time
import re
from concurrent.futures import ThreadPoolExecutor, as_completed

@dataclass
class Offer:
    price_after_gc: str
    gift_card: str
    total_price: str
    monthly_price: str
    down_payment: str
    bib_premium: str
    bib_monthly: str
    down_return: str

@dataclass
class Carrier:
    name: str
    link: str
    offers: List[Offer]

@dataclass
class Phone:
    name: str
    carriers: List[Carrier]

class BestBuyScraper:
    def __init__(self):
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        self.session = requests.Session()
        self.session.headers.update(self.headers)

    def scrape(self, xml_file_path: str) -> List[Phone]:
        phones = []

        if xml_file_path.startswith("http://") or xml_file_path.startswith("https://"):
            response = self.session.get(xml_file_path)
            response.raise_for_status()
            xml_content = response.content
            root = ET.fromstring(xml_content)
        else:
            tree = ET.parse(xml_file_path)
            root = tree.getroot()

        for phone_node in root:
            phone_name = phone_node.tag.replace('_', ' ')
            carriers = []

            urls = [(url.text, phone_name) for url in phone_node]
            with ThreadPoolExecutor() as executor:
                futures = {executor.submit(self.scrape_carrier_data, url, phone_name): url for url, phone_name in urls}

                for future in as_completed(futures):
                    try:
                        carriers.append(future.result())
                    except Exception as e:
                        print(f"Error scraping carrier data: {e}")

            phones.append(Phone(name=phone_name, carriers=carriers))

        return phones

    def extract_carrier_name(self, url: str) -> str:
        carriers = {
            'telus': 'Telus',
            'koodo': 'Koodo',
            'rogers': 'Rogers',
            'fido': 'Fido',
            'freedom-mobile': 'Freedom Mobile',
            'bell': 'Bell',
            'virgin-plus': 'Virgin Plus'
        }

        for key, value in carriers.items():
            if key in url.lower():
                return value
        return 'Unknown'

    def extract_sku_id(self, url: str) -> str:
        return url.split('/')[-1]

    def extract_cellphone_api_url(self, response: requests.Response) -> str:
        for resp_line_raw in response.iter_lines():
            resp_line = resp_line_raw.decode()
            searchprefix='cellPhonesCarrierPlansUrl'
            if searchprefix in resp_line:
                rematch = re.search(f'{searchprefix}":\".*?\"', resp_line)
                if rematch is not None:
                    apiurl = rematch.group()[len(searchprefix)+3:-1]
                    return apiurl

    def scrape_carrier_data(self, url: str, phone_name: str) -> Carrier:
        carrier_name = self.extract_carrier_name(url)
        sku_id = self.extract_sku_id(url)
        print(f"Started Extracting data for {phone_name} ({sku_id}) - {carrier_name}")

        max_retries = 3
        attempt = 1
        return_it = ['N/A']
        keep_it = ['N/A']
        while attempt <= max_retries:
            try:
                response = self.session.get(url)
                cellphone_api_url = self.extract_cellphone_api_url(response)
                request_str = re.sub('{skuId}', sku_id, cellphone_api_url)

                api_response = self.session.get(request_str)
                for offer_type in api_response.json():
                    offer_dict = offer_type
                    if 'return-it' in offer_dict['type']:
                        return_it = (str(offer_dict['monthly']), str(offer_dict['downPayment']))
                    if 'keep-it' in offer_dict['type']:
                        keep_it = (str(offer_dict['monthly']), str(offer_dict['downPayment']))
                    gift_card_amount = str(offer_dict['giftCard'])

                if keep_it[0] != 'N/A' and keep_it[0].replace('.', '').isdigit():
                    monthly_price = float(keep_it[0])
                    down_payment = float(keep_it[1]) if keep_it[1] != 'N/A' else 0
                    gift_card = float(gift_card_amount)

                    total_price = monthly_price * 24 + down_payment
                    price_after_gc = total_price - gift_card if gift_card else total_price
                    bib_monthly_price = float(return_it[0]) if return_it[0] != 'N/A' and return_it[0].replace('.', '').isdigit() else 'N/A'
                    bib_down_payment = float(return_it[1]) if return_it[0] != 'N/A' and return_it[1].replace('.', '').isdigit() else 'N/A'
                    bib_premium = (f"{total_price - (float(bib_monthly_price) * 24) - float(bib_down_payment):.2f}"
                                   if isinstance(bib_monthly_price, float) else 'N/A')

                    offer = Offer(
                        price_after_gc=str(price_after_gc),
                        gift_card=gift_card_amount,
                        total_price=f"{total_price:.2f}",
                        monthly_price=monthly_price,
                        down_payment=down_payment,
                        bib_premium=bib_premium,
                        bib_monthly=bib_monthly_price,
                        down_return=bib_down_payment
                    )
                    return Carrier(name=carrier_name, link=url, offers=[offer])

                attempt += 1
            except Exception as e:
                if attempt < max_retries:
                    print(f"Retry {attempt} - Error occurred for {phone_name} - {carrier_name}: {str(e)}")
                    time.sleep(2)
                attempt += 1

        print(f"Failed to load data after {max_retries} attempts for {phone_name} - {carrier_name}")
        return Carrier(
            name=carrier_name,
            link=url,
            offers=[Offer(
                price_after_gc='N/A',
                gift_card='0',
                total_price='N/A',
                monthly_price='N/A',
                down_payment='N/A',
                bib_premium='N/A',
                bib_monthly='N/A',
                down_return='N/A'
            )]
        )

def write_to_csv(phones: List[Phone], file_path: str):
    headers = [
        'Phone', 'Carrier', 'Price After GC', 'Gift Card Amount', 'Total Price',
        'Monthly Price', 'Downpayment', 'BIB Premium', 'BIB Monthly Price',
        'BIB Downpayment', 'Link'
    ]

    carrier_order = ['Fido', 'Rogers', 'Virgin Plus', 'Bell', 'Koodo', 'Telus', 'Freedom Mobile']

    with open(file_path, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(headers)

        for phone in phones:
            carrier_map = {carrier.name: carrier for carrier in phone.carriers}

            for carrier_name in carrier_order:
                if carrier_name in carrier_map:
                    carrier = carrier_map[carrier_name]
                    for offer in carrier.offers:
                        writer.writerow([
                            phone.name,
                            carrier.name,
                            offer.price_after_gc,
                            offer.gift_card,
                            offer.total_price,
                            offer.monthly_price,
                            offer.down_payment,
                            offer.bib_premium,
                            offer.bib_monthly,
                            offer.down_return,
                            carrier.link
                        ])
                else:
                    writer.writerow([
                        phone.name,
                        carrier_name,
                        '--', '--', '--', '--', '--', '--', '--', '--', '--'
                    ])

def main():
    scraper = BestBuyScraper()
    xml_path = "https://raw.githubusercontent.com/Herbrax/PhoneDealsScrapper/22ed5b864d6f2ca18965d8d15d4b3596e8a82c60/bestbuymobile.xml"
    phones = scraper.scrape(xml_path)

    current_date = datetime.now().strftime("%Y%m%d")
    csv_path = f"bestbuy_{current_date}_mobiles.csv"

    write_to_csv(phones, csv_path)
    print("All data has been written to CSV files.")

if __name__ == "__main__":
    main()
# Out:
# Started Extracting data for iPhone 13 128GB (15726923) - Freedom Mobile
# Started Extracting data for Samsung Galaxy S23 128GB (16667209) - Telus
# Started Extracting data for Samsung Galaxy S23 256GB (16667245) - Telus
# Started Extracting data for Samsung Galaxy S23 256GB (16667246) - KoodoStarted Extracting data for Samsung Galaxy S23 256GB (16667248) - Freedom Mobile
#
# Started Extracting data for Samsung Galaxy S23 256GB (16673194) - Rogers
# Started Extracting data for Samsung Galaxy S23 256GB (16673195) - Fido
# Started Extracting data for Samsung Galaxy S23 256GB (16673245) - Bell
# Started Extracting data for Samsung Galaxy S23 256GB (16673246) - Virgin Plus
# Started Extracting data for Samsung Galaxy S23 Plus 256GB (16667230) - Telus
# Started Extracting data for Samsung Galaxy S23 Plus 256GB (16667231) - Koodo
# Started Extracting data for Samsung Galaxy S23 Plus 256GB (16667233) - Freedom Mobile
# Started Extracting data for Samsung Galaxy S23 Plus 256GB (16673186) - Rogers
# Started Extracting data for Samsung Galaxy S23 Plus 256GB (16673187) - Fido
# Started Extracting data for Samsung Galaxy S23 Plus 256GB (16673236) - Bell
# Retry 1 - Error occurred for Samsung Galaxy S23 Plus 256GB - Freedom Mobile: string indices must be integers
# Started Extracting data for Samsung Galaxy S23 Plus 256GB (16673237) - Virgin Plus
# Retry 1 - Error occurred for Samsung Galaxy S23 Plus 256GB - Rogers: string indices must be integers
# Retry 1 - Error occurred for Samsung Galaxy S23 Plus 256GB - Fido: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Plus 256GB - Freedom Mobile: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Plus 256GB - Rogers: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Plus 256GB - Fido: string indices must be integers
# Failed to load data after 3 attempts for Samsung Galaxy S23 Plus 256GB - Rogers
# Failed to load data after 3 attempts for Samsung Galaxy S23 Plus 256GB - Fido
# Failed to load data after 3 attempts for Samsung Galaxy S23 Plus 256GB - Freedom Mobile
# Started Extracting data for Samsung Galaxy S23 Plus 512GB (16673211) - Virgin Plus
# Started Extracting data for Samsung Galaxy S23 Plus 512GB (16673256) - Bell
# Started Extracting data for Samsung Galaxy S23 Plus 512GB (16673163) - Fido
# Started Extracting data for Samsung Galaxy S23 Plus 512GB (16673162) - Rogers
# Started Extracting data for Samsung Galaxy S23 Plus 512GB (16667216) - Freedom Mobile
# Started Extracting data for Samsung Galaxy S23 Plus 512GB (16667214) - Koodo
# Started Extracting data for Samsung Galaxy S23 Plus 512GB (16667167) - Telus
# Retry 1 - Error occurred for Samsung Galaxy S23 Plus 512GB - Freedom Mobile: string indices must be integers
# Retry 1 - Error occurred for Samsung Galaxy S23 Plus 512GB - Fido: string indices must be integers
# Retry 1 - Error occurred for Samsung Galaxy S23 Plus 512GB - Rogers: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Plus 512GB - Freedom Mobile: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Plus 512GB - Fido: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Plus 512GB - Rogers: string indices must be integers
# Failed to load data after 3 attempts for Samsung Galaxy S23 Plus 512GB - Freedom Mobile
# Failed to load data after 3 attempts for Samsung Galaxy S23 Plus 512GB - Rogers
# Failed to load data after 3 attempts for Samsung Galaxy S23 Plus 512GB - Fido
# Started Extracting data for Samsung Galaxy S23 Ultra 256GB (16667181) - Telus
# Started Extracting data for Samsung Galaxy S23 Ultra 256GB (16667182) - Koodo
# Started Extracting data for Samsung Galaxy S23 Ultra 256GB (16667184) - Freedom Mobile
# Started Extracting data for Samsung Galaxy S23 Ultra 256GB (16673176) - RogersStarted Extracting data for Samsung Galaxy S23 Ultra 256GB (16673177) - Fido
#
# Started Extracting data for Samsung Galaxy S23 Ultra 256GB (16673224) - Bell
# Started Extracting data for Samsung Galaxy S23 Ultra 256GB (16673225) - Virgin Plus
# Retry 1 - Error occurred for Samsung Galaxy S23 Ultra 256GB - Rogers: string indices must be integers
# Retry 1 - Error occurred for Samsung Galaxy S23 Ultra 256GB - Fido: string indices must be integers
# Retry 1 - Error occurred for Samsung Galaxy S23 Ultra 256GB - Freedom Mobile: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Ultra 256GB - Freedom Mobile: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Ultra 256GB - Fido: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Ultra 256GB - Rogers: string indices must be integers
# Failed to load data after 3 attempts for Samsung Galaxy S23 Ultra 256GB - Freedom Mobile
# Failed to load data after 3 attempts for Samsung Galaxy S23 Ultra 256GB - Fido
# Failed to load data after 3 attempts for Samsung Galaxy S23 Ultra 256GB - Rogers
# Started Extracting data for Samsung Galaxy S23 Ultra 512GB (16673218) - Virgin Plus
# Started Extracting data for Samsung Galaxy S23 Ultra 512GB (16673217) - Bell
# Started Extracting data for Samsung Galaxy S23 Ultra 512GB (16673169) - Fido
# Started Extracting data for Samsung Galaxy S23 Ultra 512GB (16673168) - Rogers
# Started Extracting data for Samsung Galaxy S23 Ultra 512GB (16667170) - Freedom Mobile
# Started Extracting data for Samsung Galaxy S23 Ultra 512GB (16667168) - Koodo
# Started Extracting data for Samsung Galaxy S23 Ultra 512GB (16667167) - Telus
# Retry 1 - Error occurred for Samsung Galaxy S23 Ultra 512GB - Rogers: string indices must be integers
# Retry 1 - Error occurred for Samsung Galaxy S23 Ultra 512GB - Fido: string indices must be integers
# Retry 1 - Error occurred for Samsung Galaxy S23 Ultra 512GB - Freedom Mobile: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Ultra 512GB - Rogers: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Ultra 512GB - Freedom Mobile: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S23 Ultra 512GB - Fido: string indices must be integers
# Failed to load data after 3 attempts for Samsung Galaxy S23 Ultra 512GB - Rogers
# Failed to load data after 3 attempts for Samsung Galaxy S23 Ultra 512GB - Freedom Mobile
# Failed to load data after 3 attempts for Samsung Galaxy S23 Ultra 512GB - Fido
# Started Extracting data for Samsung Galaxy S24 FE 128GB (18478279) - Freedom Mobile
# Started Extracting data for Samsung Galaxy S24 FE 128GB (18478258) - Koodo
# Started Extracting data for Samsung Galaxy S24 FE 128GB (18478269) - Telus
# Started Extracting data for Samsung Galaxy S24 FE 128GB (18479060) - Fido
# Started Extracting data for Samsung Galaxy S24 FE 128GB (18479061) - Rogers
# Started Extracting data for Samsung Galaxy S24 FE 128GB (18483238) - Virgin Plus
# Started Extracting data for Samsung Galaxy S24 FE 128GB (18483239) - Bell
# Started Extracting data for Samsung Galaxy S24 FE 256GB (18478261) - Freedom Mobile
# Started Extracting data for Samsung Galaxy S24 FE 256GB (18478262) - Koodo
# Started Extracting data for Samsung Galaxy S24 FE 256GB (18478263) - Telus
# Started Extracting data for Samsung Galaxy S24 FE 256GB (18479062) - Fido
# Started Extracting data for Samsung Galaxy S24 FE 256GB (18479063) - Rogers
# Started Extracting data for Samsung Galaxy S24 FE 256GB (18483240) - Virgin Plus
# Retry 1 - Error occurred for Samsung Galaxy S24 FE 256GB - Virgin Plus: expected string or bytes-like object
# Started Extracting data for Samsung Galaxy S24 FE 256GB (18483241) - Bell
# Retry 1 - Error occurred for Samsung Galaxy S24 FE 256GB - Rogers: string indices must be integers
# Retry 1 - Error occurred for Samsung Galaxy S24 FE 256GB - Fido: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S24 FE 256GB - Virgin Plus: expected string or bytes-like object
# Retry 1 - Error occurred for Samsung Galaxy S24 FE 256GB - Bell: string indices must be integers
# Failed to load data after 3 attempts for Samsung Galaxy S24 FE 256GB - Virgin Plus
# Retry 2 - Error occurred for Samsung Galaxy S24 FE 256GB - Fido: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S24 FE 256GB - Rogers: string indices must be integers
# Retry 2 - Error occurred for Samsung Galaxy S24 FE 256GB - Bell: string indices must be integers
# Failed to load data after 3 attempts for Samsung Galaxy S24 FE 256GB - Fido
# Failed to load data after 3 attempts for Samsung Galaxy S24 FE 256GB - Rogers
# Failed to load data after 3 attempts for Samsung Galaxy S24 FE 256GB - Bell
# Started Extracting data for Samsung Galaxy S24 128GB (17684388) - BellStarted Extracting data for Samsung Galaxy S24 128GB (17684389) - Virgin Plus
#
# Started Extracting data for Samsung Galaxy S24 128GB (17667813) - Rogers
# Started Extracting data for Samsung Galaxy S24 128GB (17667812) - Fido
# Started Extracting data for Samsung Galaxy S24 128GB (17650900) - Telus
# Started Extracting data for Samsung Galaxy S24 128GB (17650899) - Koodo
# Started Extracting data for Samsung Galaxy S24 128GB (17650898) - Freedom Mobile
# Started Extracting data for Samsung Galaxy S24 256GB (17650922) - Freedom Mobile
# Started Extracting data for Samsung Galaxy S24 256GB (17650923) - Koodo
# Started Extracting data for Samsung Galaxy S24 256GB (17650924) - Telus
# Started Extracting data for Samsung Galaxy S24 256GB (17667820) - Fido
# Started Extracting data for Samsung Galaxy S24 256GB (17667821) - Rogers
# Started Extracting data for Google Pixel 9 256GB (18165739) - Koodo
# Started Extracting data for Google Pixel 9 256GB (18165738) - Telus
# Retry 1 - Error occurred for Google Pixel 9 256GB - Bell: string indices must be integers
# Retry 1 - Error occurred for Google Pixel 9 256GB - Virgin Plus: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 256GB - Bell: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 256GB - Virgin Plus: string indices must be integers
# Failed to load data after 3 attempts for Google Pixel 9 256GB - Bell
# Failed to load data after 3 attempts for Google Pixel 9 256GB - Virgin Plus
# Started Extracting data for Google Pixel 9 Pro 128GB (18165679) - Telus
# Started Extracting data for Google Pixel 9 Pro 128GB (18165692) - Koodo
# Started Extracting data for Google Pixel 9 Pro 128GB (18165693) - Freedom Mobile
# Started Extracting data for Google Pixel 9 Pro 128GB (18190280) - Rogers
# Started Extracting data for Google Pixel 9 Pro 128GB (18190281) - Fido
# Started Extracting data for Google Pixel 9 Pro 128GB (18193831) - Bell
# Started Extracting data for Google Pixel 9 Pro 128GB (18193832) - Virgin Plus
# Started Extracting data for Google Pixel 9 Pro 256GB (18165715) - Telus
# Started Extracting data for Google Pixel 9 Pro 256GB (18165716) - Koodo
# Started Extracting data for Google Pixel 9 Pro 256GB (18165717) - Freedom MobileStarted Extracting data for Google Pixel 9 Pro 256GB (18190274) - Rogers
# Started Extracting data for Google Pixel 9 Pro 256GB (18190275) - Fido
#
# Started Extracting data for Google Pixel 9 Pro 256GB (18193837) - Bell
# Started Extracting data for Google Pixel 9 Pro 256GB (18193838) - Virgin Plus
# Retry 1 - Error occurred for Google Pixel 9 Pro 256GB - Bell: string indices must be integers
# Retry 1 - Error occurred for Google Pixel 9 Pro 256GB - Virgin Plus: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 Pro 256GB - Bell: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 Pro 256GB - Virgin Plus: string indices must be integers
# Failed to load data after 3 attempts for Google Pixel 9 Pro 256GB - Bell
# Failed to load data after 3 attempts for Google Pixel 9 Pro 256GB - Virgin Plus
# Started Extracting data for Google Pixel 9 Pro 512GB (18165706) - Telus
# Started Extracting data for Google Pixel 9 Pro 512GB (18165707) - Koodo
# Started Extracting data for Google Pixel 9 Pro 512GB (18165708) - Freedom Mobile
# Started Extracting data for Google Pixel 9 Pro 512GB (18193839) - Bell
# Started Extracting data for Google Pixel 9 Pro 512GB (18193840) - Virgin Plus
# Retry 1 - Error occurred for Google Pixel 9 Pro 512GB - Virgin Plus: string indices must be integers
# Retry 1 - Error occurred for Google Pixel 9 Pro 512GB - Bell: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 Pro 512GB - Virgin Plus: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 Pro 512GB - Bell: string indices must be integers
# Failed to load data after 3 attempts for Google Pixel 9 Pro 512GB - Virgin Plus
# Failed to load data after 3 attempts for Google Pixel 9 Pro 512GB - Bell
# Started Extracting data for Google Pixel 9 Pro XL 128GB (18165686) - Telus
# Started Extracting data for Google Pixel 9 Pro XL 128GB (18165687) - Koodo
# Started Extracting data for Google Pixel 9 Pro XL 128GB (18165688) - Freedom Mobile
# Started Extracting data for Google Pixel 9 Pro XL 128GB (18190265) - RogersStarted Extracting data for Google Pixel 9 Pro XL 128GB (18190266) - Fido
#
# Started Extracting data for Google Pixel 9 Pro XL 128GB (18193861) - Virgin Plus
# Started Extracting data for Google Pixel 9 Pro XL 128GB (18193862) - Bell
# Started Extracting data for Google Pixel 9 Pro XL 256GB (18193819) - Bell
# Started Extracting data for Google Pixel 9 Pro XL 256GB (18193820) - Virgin Plus
# Started Extracting data for Google Pixel 9 Pro XL 256GB (18190270) - Fido
# Started Extracting data for Google Pixel 9 Pro XL 256GB (18190264) - Rogers
# Started Extracting data for Google Pixel 9 Pro XL 256GB (18165685) - Freedom Mobile
# Started Extracting data for Google Pixel 9 Pro XL 256GB (18165684) - Koodo
# Started Extracting data for Google Pixel 9 Pro XL 256GB (18165683) - Telus
# Retry 1 - Error occurred for Google Pixel 9 Pro XL 256GB - Virgin Plus: string indices must be integers
# Retry 1 - Error occurred for Google Pixel 9 Pro XL 256GB - Bell: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 Pro XL 256GB - Virgin Plus: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 Pro XL 256GB - Bell: string indices must be integers
# Failed to load data after 3 attempts for Google Pixel 9 Pro XL 256GB - Virgin Plus
# Failed to load data after 3 attempts for Google Pixel 9 Pro XL 256GB - Bell
# Started Extracting data for Google Pixel 9 Pro XL 512GB (18165729) - TelusStarted Extracting data for Google Pixel 9 Pro XL 512GB (18165730) - Koodo
#
# Started Extracting data for Google Pixel 9 Pro XL 512GB (18165731) - Freedom MobileStarted Extracting data for Google Pixel 9 Pro XL 512GB (18193821) - Bell
# Started Extracting data for Google Pixel 9 Pro XL 512GB (18193822) - Virgin Plus
#
# Retry 1 - Error occurred for Google Pixel 9 Pro XL 512GB - Bell: string indices must be integers
# Retry 1 - Error occurred for Google Pixel 9 Pro XL 512GB - Virgin Plus: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 Pro XL 512GB - Bell: string indices must be integers
# Retry 2 - Error occurred for Google Pixel 9 Pro XL 512GB - Virgin Plus: string indices must be integers
# Failed to load data after 3 attempts for Google Pixel 9 Pro XL 512GB - Bell
# Failed to load data after 3 attempts for Google Pixel 9 Pro XL 512GB - Virgin Plus
# Started Extracting data for Google Pixel 9 Pro Fold 256GB (18165735) - Telus
# Started Extracting data for Google Pixel 9 Pro Fold 256GB (18165736) - Koodo
# Started Extracting data for Google Pixel 9 Pro Fold 256GB (18165737) - Freedom Mobile
# Started Extracting data for Google Pixel 9 Pro Fold 512GB (18165672) - Freedom Mobile
# Started Extracting data for Google Pixel 9 Pro Fold 512GB (18165671) - Koodo
# Started Extracting data for Google Pixel 9 Pro Fold 512GB (18165670) - Telus
# All data has been written to CSV files.
